# %%
import pandas as pd
import matplotlib as plt

# %%
data = pd.read_csv('state_level_data.csv')

# %%
data
# Out:
#    state  Total.3.years.and.older  \
# 0     AK                      673
# 1     AL                     4552
# 2     AR                     2789
# 3     AZ                     6213
# 4     CA                    35929
# 5     CO                     4885
# 6     CT                     3433
# 7     DC                      603
# 8     DE                      870
# 9     FL                    18403
# 10    GA                     9370
# 11    HI                     1285
# 12    IA                     2933
# 13    ID                     1519
# 14    IL                    12191
# 15    IN                     6247
# 16    KS                     2714
# 17    KY                     4112
# 18    LA                     4323
# 19    MA                     6331
# 20    MD                     5601
# 21    ME                     1274
# 22    MI                     9440
# 23    MN                     5148
# 24    MO                     5709
# 25    MS                     2801
# ...

# %%
from pandas.io import sql
import MySQLdb as db

#Open connection to mysql database
con = db.connect('localhost','root','','FCC')

#Write dataframe to mysql database
data.to_sql(con=con, name='FCC', if_exists='replace', flavor='mysql')

# %%
ax = data.percapita.plot(kind='bar',color='grey',grid=False)
labs = ax.get_xticklabels()
for lab in labs:
    lab.set_fontsize(6)
    lab.set_rotation(0)
ax.figure.set_figwidth(9)
ax.figure.set_figheight(3)
ax.figure.savefig('state_dist.png',dpi=200)

# %%
import vincent

# %%
#state_data = pd.read_csv(state_unemployment)
vis.tabular_data(data, columns=['state', 'percapita'])

# %%
vis.geo_data(bind_data='data.id', reset=True, states=state_geo)
vis.update_map(scale=1000, projection='albersUsa')
vis + (['#c9cedb', '#0b0d11'], 'scales', 0, 'range')
vis.to_json(path)
